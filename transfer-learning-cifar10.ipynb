# %% [markdown]
# # Task: Transfer Learning & Classification
# Utilizing pre trained "densenet161" model for a custome classification of CIFAR-10

# %% [markdown]
# ## Imports

# %%
import os
from pathlib import Path
import fastprogress
import time

from fastprogress import progress_bar, master_bar
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torchvision
from torchinfo import summary


torch.set_float32_matmul_precision('high')

# %% [markdown]
# ### Helper functions

# %%
def get_mean_std(dataloader):

    mean = 0.0
    std = 0.0
    for images, _ in dataloader:
        batch_samples = images.size(0)
        images = images.view(batch_samples, images.size(1), -1)
        mean += images.mean(2).sum(0)
        std += images.std(2).sum(0)

    mean /= len(dataloader.dataset)
    std /= len(dataloader.dataset)

    return mean, std


def get_device(cuda_id=0):
    use_cuda = torch.cuda.is_available()
    device = torch.device(f'cuda:{cuda_id}' if use_cuda else 'cpu')
    device_name = torch.cuda.get_device_name(device) if use_cuda else 'cpu'
    print('Using device', device_name)
    return device


def load_cifar10(path, train, transform=torchvision.transforms.ToTensor()):
    return torchvision.datasets.CIFAR10(path, train=train, download=True, 
                                        transform=transform)


def get_dataLoader(data, batch_size=128, shuffle=False, num_workers=2, collate_fn=None):
    return torch.utils.data.DataLoader(data,batch_size=batch_size,
                                       shuffle=shuffle,num_workers=num_workers,collate_fn=collate_fn)


def show_images(loader, title='', feature_names=None):
    """show 6 images from dataloader"""
    plt.close('all')
    sns.set_theme(
        style='whitegrid',
        rc={'figure.figsize': (12, 5), 'font.size': 14}
    )

    x, y = next(iter(loader))
    idx = np.random.randint(0, x.shape[0], 12)
    fig, ax = plt.subplots(2, 6)
    fig.suptitle(title)

    for axs, i in zip(ax.flatten(), idx):
        if x.shape[1] == 3:
            axs.imshow(x[i].permute(1,2,0))
        else:
            axs.imshow(x[i].permute(1,2,0), cmap='gray')
        axs.axis(False)
        class_name = y[i].item()
        if feature_names is not None:
            class_name = feature_names[class_name]
        axs.set_title(f"{class_name}")

    plt.show()

# %% [markdown]
# ### CUDA Check

# %%
device = get_device()
# Out:
# Using device NVIDIA A100 80GB PCIe

# %% [markdown]
# ### Paths

# %%
path = Path().cwd()

data_folder = path / 'data'
data_folder.mkdir(exist_ok=True)

checkpoint_folder = path / 'checkpoint'
checkpoint_folder.mkdir(exist_ok=True)

data_folder, checkpoint_folder
# Out:
# (PosixPath('/home/ah19/Course Assignments/data'),
#  PosixPath('/home/ah19/Course Assignments/checkpoint'))

# %% [markdown]
# ### Load & normalize data

# %%
# load train data
traindata = load_cifar10(data_folder, train=True)
# Out:
# Files already downloaded and verified

# %%
# get mean and std for normalization
trainloader = get_dataLoader(traindata)

# calculate manually
# mean_, std_ = get_mean_std(trainloader)

# already calculated
mean_ = torch.tensor((0.4914, 0.4822, 0.4465))
std_ = torch.tensor((0.2023, 0.1994, 0.2010))

mean_, std_
# Out:
# (tensor([0.4914, 0.4822, 0.4465]), tensor([0.2023, 0.1994, 0.2010]))

# %%
# train transformer with data augmentation
tf_train = torchvision.transforms.Compose([
    torchvision.transforms.RandomHorizontalFlip(),
    torchvision.transforms.RandomCrop(32, 4),
    torchvision.transforms.ToTensor(),
    torchvision.transforms.Normalize(mean_, std_)
])

# test transformer
tf_test = torchvision.transforms.Compose([
    torchvision.transforms.ToTensor(),
    torchvision.transforms.Normalize(mean_, std_)
])

# %% [markdown]
# ### EDA

# %%
# classes
classes = ['plane', 'car', 'bird',
           'cat', 'deer', 'dog',
           'frog', 'horse', 'ship',
           'truck']

show_images(trainloader, feature_names=classes)

# %%
ax = sns.barplot(x=classes, y=np.bincount(traindata.targets, minlength=10), hatch='x', color='teal')
ax.set_title('Train data - Balanced')

plt.show()

# %% [markdown]
# ### Load train and test

# %%
traindata = load_cifar10(data_folder, train=True, transform=tf_train)
testdata =  load_cifar10(data_folder, train=False, transform=tf_test)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# ### Download DenseNet and add custom layer

# %%
from torchvision.models import densenet161

# mobilenet_v3_large

# %%
class Cifar10_DenseNet(nn.Module):
    def __init__(self):
        super(Cifar10_DenseNet, self).__init__()
        # load weights from pre trained
        self.model = densenet161(weights='DEFAULT')
        # change last layer to adapt for cifar-10 classes
        # if needed add extra layers here
        self.tl.classifier = nn.Linear(self.tl.classifier.in_features, 10)


    def forward(self, x):
        x = self.tl(x)
        return x

# %% [markdown]
# ### Initaite model

# %%
model = Cifar10_DenseNet().to(device)

# to allow only named layers to train
# params_to_train = [
#     'tl.classifier.weight',
# #     'bn.weight',
# #     'bn.bias',
# #     'output.weight'
# ]

# for name, param in model.named_parameters():
#     if name in params_to_train:
#         print(name)
#         param.requires_grad = True
#     else:
#         param.requires_grad =False

model = torch.compile(model)

# %% [markdown]
# ### Optimizer and learning scheduler

# %%
lr = 1e-3
epochs = 50
batch_size = 64
optim_name = 'AdamW'
scheduler_name = 'MultiStepLR'


optimizer = getattr(torch.optim, optim_name)(model.parameters(), lr=lr)
scheduler = getattr(torch.optim.lr_scheduler, scheduler_name)(optimizer, milestones=[20, 40])

# %% [markdown]
# ### Dataloaders

# %%
trainloader = get_dataLoader(traindata, batch_size=batch_size, shuffle=True)
testloader = get_dataLoader(testdata, batch_size=batch_size, shuffle=False)

# %% [markdown]
# ### Loss function

# %%
cost_fn = nn.CrossEntropyLoss()

# %% [markdown]
# ### Train and Test

# %%
losses = []
accuracies = []

best_accuracy = 0.0
best_loss = 1.0
current_accuracy = 0.0
current_patience = 0

mb = master_bar(range(epochs))

for epoch in mb:

    model.train()
    train_loss = 0.0
    
    for x, y in progress_bar(trainloader, parent=mb):
        
        mb.child.comment = "Training"
        
        # Move tensors to device
        x = x.to(device)
        y = y.to(device)

        # Forward pass
        outputs = model(x)
        loss = cost_fn(outputs, y)

        # Backward pass and optimization
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        train_loss += loss.item()

    # Testing phase
    model.eval()
    total_correct = 0
    total_number = 0
    with torch.no_grad():
        for x, y in progress_bar(testloader, parent=mb):
            
            mb.child.comment = "Testing"
        
            # Move tensors to device
            x = x.to(device)
            y = y.to(device)

            outputs = model(x)
            loss = cost_fn(outputs, y)
            _, predicted = torch.max(outputs.data, 1)
            total_number += y.size(0)
            total_correct += (predicted == y).sum().item()

    # calculate accuracy
    current_accuracy = 100 * total_correct / total_number
    
    # append test accuracy and loss
    accuracies.append(current_accuracy)
    losses.append(loss.item())
    
    # check improvement in accuracy and patiens
    if current_accuracy > best_accuracy:
        best_accuracy = current_accuracy
        best_loss = loss.item()
        current_patience = 0
        torch.save(model.state_dict(), checkpoint_folder / f'cifar10-checkpoint-tl.pth.tar')
        
        
    # ctep scheduler
    scheduler.step()
        
    # Print epoch information
    mb.write(f"Epoch [{epoch+1:03}], LR: {scheduler.get_last_lr()[0]:.1e}, Accuracy: {current_accuracy:.2f}%, Loss: {loss.item():.2f}%") 

print(f"Best Accuracy: {best_accuracy:.2f}%")
# Out:
# Epoch [001], LR: 1.0e-03, Accuracy: 72.85%, Loss: 0.75%<p>Epoch [002], LR: 1.0e-03, Accuracy: 71.63%, Loss: 1.21%<p>Epoch [003], LR: 1.0e-03, Accuracy: 75.03%, Loss: 0.75%<p>Epoch [004], LR: 1.0e-03, Accuracy: 71.02%, Loss: 2.21%<p>Epoch [005], LR: 1.0e-03, Accuracy: 83.73%, Loss: 0.54%<p>Epoch [006], LR: 1.0e-03, Accuracy: 82.88%, Loss: 0.69%<p>Epoch [007], LR: 1.0e-03, Accuracy: 81.79%, Loss: 0.99%<p>Epoch [008], LR: 1.0e-03, Accuracy: 84.33%, Loss: 0.54%<p>Epoch [009], LR: 1.0e-03, Accuracy: 85.38%, Loss: 0.42%<p>Epoch [010], LR: 1.0e-03, Accuracy: 85.50%, Loss: 0.19%<p>Epoch [011], LR: 1.0e-03, Accuracy: 84.31%, Loss: 0.47%<p>Epoch [012], LR: 1.0e-03, Accuracy: 85.97%, Loss: 0.47%<p>Epoch [013], LR: 1.0e-03, Accuracy: 85.48%, Loss: 0.36%<p>Epoch [014], LR: 1.0e-03, Accuracy: 86.04%, Loss: 0.27%<p>Epoch [015], LR: 1.0e-03, Accuracy: 85.82%, Loss: 0.39%<p>Epoch [016], LR: 1.0e-03, Accuracy: 85.70%, Loss: 0.38%<p>Epoch [017], LR: 1.0e-03, Accuracy: 86.22%, Loss: 0.27%<p>Epoch [018], LR: 1.0e-03, Accuracy: 87.62%, Loss: 0.54%<p>Epoch [019], LR: 1.0e-03, Accuracy: 86.98%, Loss: 0.13%<p>Epoch [020], LR: 1.0e-04, Accuracy: 86.61%, Loss: 0.43%<p>Epoch [021], LR: 1.0e-04, Accuracy: 89.13%, Loss: 0.26%<p>Epoch [022], LR: 1.0e-04, Accuracy: 89.49%, Loss: 0.24%<p>Epoch [023], LR: 1.0e-04, Accuracy: 89.73%, Loss: 0.32%<p>Epoch [024], LR: 1.0e-04, Accuracy: 89.45%, Loss: 0.31%<p>Epoch [025], LR: 1.0e-04, Accuracy: 89.74%, Loss: 0.33%<p>Epoch [026], LR: 1.0e-04, Accuracy: 89.71%, Loss: 0.43%<p>Epoch [027], LR: 1.0e-04, Accuracy: 89.70%, Loss: 0.34%<p>Epoch [028], LR: 1.0e-04, Accuracy: 89.65%, Loss: 0.33%<p>Epoch [029], LR: 1.0e-04, Accuracy: 89.56%, Loss: 0.42%<p>Epoch [030], LR: 1.0e-04, Accuracy: 89.79%, Loss: 0.35%<p>Epoch [031], LR: 1.0e-04, Accuracy: 89.59%, Loss: 0.44%<p>Epoch [032], LR: 1.0e-04, Accuracy: 89.57%, Loss: 0.58%<p>Epoch [033], LR: 1.0e-04, Accuracy: 89.67%, Loss: 0.43%<p>Epoch [034], LR: 1.0e-04, Accuracy: 89.84%, Loss: 0.49%<p>Epoch [035], LR: 1.0e-04, Accuracy: 89.64%, Loss: 0.41%<p>Epoch [036], LR: 1.0e-04, Accuracy: 89.72%, Loss: 0.49%<p>Epoch [037], LR: 1.0e-04, Accuracy: 89.53%, Loss: 0.42%<p>Epoch [038], LR: 1.0e-04, Accuracy: 89.78%, Loss: 0.33%<p>Epoch [039], LR: 1.0e-04, Accuracy: 89.71%, Loss: 0.44%<p>Epoch [040], LR: 1.0e-05, Accuracy: 89.88%, Loss: 0.53%<p>Epoch [041], LR: 1.0e-05, Accuracy: 89.89%, Loss: 0.51%<p>Epoch [042], LR: 1.0e-05, Accuracy: 89.99%, Loss: 0.53%<p>Epoch [043], LR: 1.0e-05, Accuracy: 90.02%, Loss: 0.45%<p>Epoch [044], LR: 1.0e-05, Accuracy: 90.04%, Loss: 0.52%<p>Epoch [045], LR: 1.0e-05, Accuracy: 90.15%, Loss: 0.51%<p>Epoch [046], LR: 1.0e-05, Accuracy: 90.00%, Loss: 0.44%<p>Epoch [047], LR: 1.0e-05, Accuracy: 89.91%, Loss: 0.48%<p>Epoch [048], LR: 1.0e-05, Accuracy: 90.01%, Loss: 0.47%<p>Epoch [049], LR: 1.0e-05, Accuracy: 89.85%, Loss: 0.50%<p>Epoch [050], LR: 1.0e-05, Accuracy: 90.10%, Loss: 0.49%
# Best Accuracy: 90.15%

# %%
# rename checkpoint
best_model = checkpoint_folder / f'cifar10-checkpoint-tl.pth.tar'
best_model.rename(checkpoint_folder / f'cifar10-checkpoint-tl-acc_{best_accuracy:.2f}-loss{best_loss:.2f}.pth.tar')
# Out:
# PosixPath('/home/ah19/Course Assignments/checkpoint/cifar10-checkpoint-tl-acc_90.15-loss0.51.pth.tar')

# %% [markdown]
# ### Plot accuracy and loss

# %%
best_epoch_idx = np.argmax(accuracies)

# %%
ax = pd.DataFrame({'accuracy': accuracies}, index=range(1, len(accuracies)+1)) \
    .plot(title='Best Accuracy', color='orange')

ax.scatter(x=best_epoch_idx+1, y=accuracies[best_epoch_idx], color='darkgreen', s=50, marker='o', zorder=3)
ax.annotate(f'Accuracy: {accuracies[best_epoch_idx]:.2f}%', (best_epoch_idx+1, accuracies[best_epoch_idx]*0.95))

plt.show()

# %%
ax = pd.DataFrame({'loss': losses}, index=range(1, len(accuracies)+1)) \
    .plot(title='Best Accuracy\'s Loss', color='red')

ax.scatter(x=best_epoch_idx+1, y=losses[best_epoch_idx], color='darkgreen', s=50, marker='o', zorder=3)
ax.annotate(f'Loss: {losses[best_epoch_idx]:.2f}%', (best_epoch_idx+1, losses[best_epoch_idx]*1.2))

plt.show()
